# %% [markdown]
# # Welcome to our Lab practice!
#
# This lab is all about the package, Matplotlib. Are you ready? Let's go!
#
# You will find some small tasks in sections below.
#
# > Try to figure out by yourself, or search for references. Being able to search and find information needed is an important skill that benefits you and your career for a long time.
#
# > Please note this lab is exploratory, and there is no correct solution -- Just try your best!
#
# ### Choose One dataset from the list below, and play with it.
#
# For practice purpose, you can load and play with one or more toy datasets in seaborn package (we are going to learn it in next module). You can get them by:
#
# ```
# import seaborn as sns
# data = sns.load_dataset('NAME')
# ```
#
# The list of names can be found at [Seaborn Datasets](https://github.com/mwaskom/seaborn-data):
#
# ```
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes',
#  'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser',
# 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']
# ```
#
# For example, to play with the dataset *iris*, you can do:
#
# ```
# import seaborn as sns
# data = sns.load_dataset('iris')
# ```

# %% [markdown]
# ## Set up the environment

# %% [markdown]
# ### Task: import packages and rename them accordingly

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load the dataset

# %%
import seaborn as sns
data = sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Play with distribution plots
# You can show the data distribution for some attributes interest you.

# %%
plt.hist(data[data['species']=='setosa']['petal_length'], bins=10, color='y')
plt.xlabel('petal_length')
plt.ylabel('distribution')
# Out:
# Text(0, 0.5, 'distribution')

# %% [markdown]
# ## Play with relational plots
# You can show how two or more attributes are associated.

# %%
plt.scatter(
    x=data[data['species']=='virginica']['petal_length'],
    y=data[data['species']=='virginica']['petal_width'],
    c='b',
    marker='o')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
# Out:
# Text(0, 0.5, 'petal_width')

# %% [markdown]
# ## Play with other plots
# You can play with other plots we learned here. Be as creative as you can and see how the visualization helps you to understand the data better.

# %%
plt.pie(x=data.groupby('species')['sepal_width'].mean(), 
        labels=data['species'].unique(),autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x26366fded50>,
#   <matplotlib.patches.Wedge at 0x26366fdfa90>,
#   <matplotlib.patches.Wedge at 0x26366ff0390>],
#  [Text(0.42495154807303587, 1.0146014891524309, 'setosa'),
#   Text(-1.0867269531610126, -0.17036586886281627, 'versicolor'),
#   Text(0.5769634230249335, -0.9365432229701691, 'virginica')],
#  [Text(0.23179175349438316, 0.5534189940831441, '37.4%'),
#   Text(-0.5927601562696432, -0.09292683756153614, '30.2%'),
#   Text(0.3147073216499637, -0.5108417579837286, '32.4%')])

# %% [markdown]
# ## Additional Challenge
# You may want to create new columns based on existing data using Pandas. You can play with the new columns as well.

# %%
data['total_length']=data['sepal_length']+data['petal_length']
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  total_length
# 0           5.1          3.5           1.4          0.2  setosa           6.5
# 1           4.9          3.0           1.4          0.2  setosa           6.3
# 2           4.7          3.2           1.3          0.2  setosa           6.0
# 3           4.6          3.1           1.5          0.2  setosa           6.1
# 4           5.0          3.6           1.4          0.2  setosa           6.4

# %%
plt.plot(data['total_length'])

# %%
plt.pie(x=data.groupby(data['species'])['total_length'].sum(),labels=data['species'].unique(),autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x26366fc2690>,
#   <matplotlib.patches.Wedge at 0x263670ab190>,
#   <matplotlib.patches.Wedge at 0x263670bc750>],
#  [Text(0.8374508475532089, 0.7132153096593008, 'setosa'),
#   Text(-0.8961389937463606, 0.6379144957494385, 'versicolor'),
#   Text(0.26863815928752405, -1.0666928045949364, 'virginica')],
#  [Text(0.45679137139265935, 0.38902653254143676, '22.5%'),
#   Text(-0.4888030874980148, 0.34795336131787546, '35.4%'),
#   Text(0.14652990506592217, -0.5818324388699653, '42.1%')])
